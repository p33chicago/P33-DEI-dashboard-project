# %% [markdown]
# # Data ingestion
#
# Currently, this notebook reads raw data files from the local filesystem and applies some basic transformations. In the future, we might also download files from their upstream source (e.g. CPS webserver).
#
# **Note:** this is an R notebook, so make sure you're using the R Jupyter Kernel (not Python)

# %%
source("ingest.r")
df_DEI_parametric_tidy
# Out:
# also installing the dependency ‘gridExtra’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer
#
#
# Classes and Methods for R developed in the
# Political Science Computational Laboratory
# Department of Political Science
# Stanford University
# Simon Jackman
# hurdle and zeroinfl functions by Achim Zeileis
#
#
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#     var_dim
# 1   access
# 2   access
# 3   access
# 4   access
# 5   access
# 6   access
# 7   access
# 8   access
# 9   access
# 10  access
# 11  access
# 12  access
# 13  access
# 14  access
# 15  access
# 16  access
# 17  access
# 18  access
# 19  access
# 20  access
# 21  access
# 22  access
# 23  access
# 24  access
# 25  access
# 26  access
# 27  access
# 28  access
# 29  excellence
# 30  excellence
# ⋮   ⋮
# 412 NA
# 413 NA
# 414 NA
# 415 NA
# 416 NA
# 417 NA
# 418 NA
# 419 NA
# 420 NA
# 421 NA
# 422 NA
# 423 NA
# 424 NA
# 425 NA
# 426 NA
# 427 NA
# 428 excellence
# 429 excellence
# 430 excellence
# 431 excellence
# 432 excellence
# 433 excellence
# 434 excellence
# 435 access
# 436 access
# 437 access
# 438 access
# 439 access
# 440 access
# 441 access
#     Demographic                                                         var_yr
# 1   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 2   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 3   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 4   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 5   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 6   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 7   4th graders with elementary schools offering cs usa (amazon survey) 2021
# 8   usa interest in cs 5th-8th grade (amazon survey)                    2021
# 9   usa interest in cs 5th-8th grade (amazon survey)                    2021
# 10  usa interest in cs 5th-8th grade (amazon survey)                    2021
# 11  usa interest in cs 5th-8th grade (amazon survey)                    2021
# 12  usa interest in cs 5th-8th grade (amazon survey)                    2021
# 13  usa interest in cs 5th-8th grade (amazon survey)                    2021
# 14  usa interest in cs 5th-8th grade (amazon survey)                    2021
# 15  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 16  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 17  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 18  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 19  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 20  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 21  usa interest in cs 9th-12th grade (amazon survey)                   2021
# 22  usa hs offering cs (amazon survey)                                  2021
# 23  usa hs offering cs (amazon survey)                                  2021
# 24  usa hs offering cs (amazon survey)                                  2021
# 25  usa hs offering cs (amazon survey)                                  2021
# 26  usa hs offering cs (amazon survey)                                  2021
# 27  usa hs offering cs (amazon survey)                                  2021
# 28  usa hs offering cs (amazon survey)                                  2021
# 29  carnegie mellon cs enrollment demographics (college factual)        2021
# 30  carnegie mellon cs enrollment demographics (college factual)        2021
# ⋮   ⋮                                                                   ⋮
# 412 cps hs students interested in computer science (foia)               2021
# 413 cps hs students interested in computer science (foia)               2021
# 414 cps hs dual credit completion in cs (foia)                          2021
# 415 cps hs dual credit completion in cs (foia)                          2021
# 416 cps hs dual credit completion in cs (foia)                          2021
# 417 cps hs dual credit completion in cs (foia)                          2021
# 418 cps hs dual credit completion in cs (foia)                          2021
# 419 cps hs dual credit completion in cs (foia)                          2021
# 420 cps hs dual credit completion in cs (foia)                          2021
# 421 cps 8th grade cps failing algebra (ocr)                             2017
# 422 cps 8th grade cps failing algebra (ocr)                             2017
# 423 cps 8th grade cps failing algebra (ocr)                             2017
# 424 cps 8th grade cps failing algebra (ocr)                             2017
# 425 cps 8th grade cps failing algebra (ocr)                             2017
# 426 cps 8th grade cps failing algebra (ocr)                             2017
# 427 cps 8th grade cps failing algebra (ocr)                             2017
# 428 cps hs enrolled in advanced math (ocr)                              2017
# 429 cps hs enrolled in advanced math (ocr)                              2017
# 430 cps hs enrolled in advanced math (ocr)                              2017
# 431 cps hs enrolled in advanced math (ocr)                              2017
# 432 cps hs enrolled in advanced math (ocr)                              2017
# 433 cps hs enrolled in advanced math (ocr)                              2017
# 434 cps hs enrolled in advanced math (ocr)                              2017
# 435 cps 8th graders enrolled in algebra (ocr 2017)                      2017
# 436 cps 8th graders enrolled in algebra (ocr 2017)                      2017
# 437 cps 8th graders enrolled in algebra (ocr 2017)                      2017
# 438 cps 8th graders enrolled in algebra (ocr 2017)                      2017
# 439 cps 8th graders enrolled in algebra (ocr 2017)                      2017
# 440 cps 8th graders enrolled in algebra (ocr 2017)                      2017
# 441 cps 8th graders enrolled in algebra (ocr 2017)                      2017
#     var_scope var_stage var_key            var_est var_sample note
# 1   usa       k8_4th    cs_classOffered    no      1
# 2   usa       k8_4th    cs_classOffered    no      1
# 3   usa       k8_4th    cs_classOffered    no      1
# 4   usa       k8_4th    cs_classOffered    no      1
# 5   usa       k8_4th    cs_classOffered    no      1
# 6   usa       k8_4th    cs_classOffered    no      1
# 7   usa       k8_4th    cs_classOffered    no      1
# 8   usa       k8_5to8th cs_interested      yes     1
# 9   usa       k8_5to8th cs_interested      yes     1
# 10  usa       k8_5to8th cs_interested      yes     1
# 11  usa       k8_5to8th cs_interested      yes     1
# 12  usa       k8_5to8th cs_interested      yes     1
# 13  usa       k8_5to8th cs_interested      yes     1
# 14  usa       k8_5to8th cs_interested      yes     1
# 15  usa       hs        cs_interested      yes     1
# 16  usa       hs        cs_interested      yes     1
# 17  usa       hs        cs_interested      yes     1
# 18  usa       hs        cs_interested      yes     1
# 19  usa       hs        cs_interested      yes     1
# 20  usa       hs        cs_interested      yes     1
# 21  usa       hs        cs_interested      yes     1
# 22  usa       hs        cs_classOffered    no      1
# 23  usa       hs        cs_classOffered    no      1
# 24  usa       hs        cs_classOffered    no      1
# 25  usa       hs        cs_classOffered    no      1
# 26  usa       hs        cs_classOffered    no      1
# 27  usa       hs        cs_classOffered    no      1
# 28  usa       hs        cs_classOffered    no      1
# 29  college   col       t3_mellon_cs_enrol yes     0
# 30  college   col       t3_mellon_cs_enrol yes     0
# ⋮   ⋮         ⋮         ⋮                  ⋮       ⋮          ⋮
# 412 city_chi  hs        NA                 no      0
# 413 city_chi  hs        NA                 no      0
# 414 city_chi  hs        NA                 no      0
# 415 city_chi  hs        NA                 no      0
# 416 city_chi  hs        NA                 no      0
# 417 city_chi  hs        NA                 no      0
# 418 city_chi  hs        NA                 no      0
# 419 city_chi  hs        NA                 no      0
# 420 city_chi  hs        NA                 no      0
# 421 city_chi  k8_8th    NA                 no      0
# 422 city_chi  k8_8th    NA                 no      0
# 423 city_chi  k8_8th    NA                 no      0
# 424 city_chi  k8_8th    NA                 no      0
# 425 city_chi  k8_8th    NA                 no      0
# 426 city_chi  k8_8th    NA                 no      0
# 427 city_chi  k8_8th    NA                 no      0
# 428 city_chi  hs        NA                 no      0
# 429 city_chi  hs        NA                 no      0
# 430 city_chi  hs        NA                 no      0
# 431 city_chi  hs        NA                 no      0
# 432 city_chi  hs        NA                 no      0
# 433 city_chi  hs        NA                 no      0
# 434 city_chi  hs        NA                 no      0
# 435 city_chi  k8_8th    NA                 no      0
# 436 city_chi  k8_8th    NA                 no      0
# 437 city_chi  k8_8th    NA                 no      0
# 438 city_chi  k8_8th    NA                 no      0
# 439 city_chi  k8_8th    NA                 no      0
# 440 city_chi  k8_8th    NA                 no      0
# 441 city_chi  k8_8th    NA                 no      0
#     var_source      var_type var_ethinc     var_value
# 1   amazon survey   prob     all              0.0038
# 2   amazon survey   prob     black_hispanic   0.0061
# 3   amazon survey   prob     white_asian      0.0079
# 4   amazon survey   prob     black            0.0026
# 5   amazon survey   prob     hispanic         0.0035
# 6   amazon survey   prob     white            0.0036
# 7   amazon survey   prob     asian            0.0043
# 8   amazon survey   prob     all              0.0053
# 9   amazon survey   prob     black_hispanic   0.0103
# 10  amazon survey   prob     white_asian      0.0115
# 11  amazon survey   prob     black            0.0051
# 12  amazon survey   prob     hispanic         0.0052
# 13  amazon survey   prob     white            0.0054
# 14  amazon survey   prob     asian            0.0061
# 15  amazon survey   prob     all              0.0069
# 16  amazon survey   prob     black_hispanic   0.0135
# 17  amazon survey   prob     white_asian      0.0149
# 18  amazon survey   prob     black            0.0067
# 19  amazon survey   prob     hispanic         0.0068
# 20  amazon survey   prob     white            0.0070
# 21  amazon survey   prob     asian            0.0079
# 22  amazon survey   prob     all              0.0078
# 23  amazon survey   prob     black_hispanic   0.0149
# 24  amazon survey   prob     white_asian      0.0168
# 25  amazon survey   prob     black            0.0073
# 26  amazon survey   prob     hispanic         0.0076
# 27  amazon survey   prob     white            0.0079
# 28  amazon survey   prob     asian            0.0089
# 29  college factual count    all            600.0000
# 30  college factual count    black_hispanic  71.0000
# ⋮   ⋮               ⋮        ⋮              ⋮
# 412 foia            count    white           1905
# 413 foia            count    asian           1081
# 414 foia            count    all              297
# 415 foia            count    black_hispanic   273
# 416 foia            count    white_asian       24
# 417 foia            count    black            157
# 418 foia            count    hispanic         116
# 419 foia            count    white             19
# 420 foia            count    asian              5
# 421 ocr             count    all               88
# 422 ocr             count    black_hispanic    84
# 423 ocr             count    white_asian        4
# 424 ocr             count    black             55
# 425 ocr             count    hispanic          29
# 426 ocr             count    white              4
# 427 ocr             count    asian              0
# 428 ocr             count    all            31802
# 429 ocr             count    black_hispanic 26227
# 430 ocr             count    white_asian     5575
# 431 ocr             count    black          10952
# 432 ocr             count    hispanic       15275
# 433 ocr             count    white           3728
# 434 ocr             count    asian           1847
# 435 ocr 2017        count    all             5749
# 436 ocr 2017        count    black_hispanic  3916
# 437 ocr 2017        count    white_asian     1833
# 438 ocr 2017        count    black           1138
# 439 ocr 2017        count    hispanic        2778
# 440 ocr 2017        count    white           1286
# 441 ocr 2017        count    asian            547
